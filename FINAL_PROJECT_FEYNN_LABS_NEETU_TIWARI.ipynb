# %% [markdown]
# <a href="https://colab.research.google.com/github/NeetuTiwari22/Feynn-labs-project/blob/main/FINAL_PROJECT_FEYNN_LABS_NEETU_TIWARI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Districtwise
import pandas as pd
df = pd.read_csv('/content/2015_16_Districtwise.csv')
df.head()
# Out:
#    AC_YEAR  STATCD  DISTCD         STATNAME  DISTNAME  DISTRICTS  BLOCKS  \
# 0  2015-16       1     101  JAMMU & KASHMIR   KUPWARA          1      13
# 1  2015-16       1     102  JAMMU & KASHMIR  BARAMULA          1      18
# 2  2015-16       1     103  JAMMU & KASHMIR  SRINAGAR          1       8
# 3  2015-16       1     104  JAMMU & KASHMIR    BADGAM          1      13
# 4  2015-16       1     105  JAMMU & KASHMIR   PULWAMA          1       8
#
#    VILLAGES  CLUSTERS  TOTPOPULAT  ...  UUNI_ALL  UUNI_SC  UUNI_ST  TOTCLS1G  \
# 0       391       104    875564.0  ...     21322       26     2594      3489
# 1       678       144   1015503.0  ...     17307        0     1571      4127
# 2        94        65   1269751.0  ...      5444       31      408       817
# 3       523       104    735753.0  ...     12469       18      857      2290
# 4       359        64    570060.0  ...      7408       17      855      1688
#
#    TOTCLS2G  TOTCLS3G  TOTCLS4G  TOTCLS5G  TOTCLS6G  TOTCLS7G
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_4.groupby('DISTNAME').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_16['CLUSTERS'].plot(kind='line', figsize=(8, 4), title='CLUSTERS')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['STATCD']
  ys = series['TOTPOPULAT']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_12.sort_values('STATCD', ascending=True)
for i, (series_name, series) in enumerate(df_sorted.groupby('DISTNAME')):
  _plot_series(series, series_name, i)
  fig.legend(title='DISTNAME', bbox_to_anchor=(1, 1), loc='upper left')
sns.despine(fig=fig, ax=ax)
plt.xlabel('STATCD')
_ = plt.ylabel('TOTPOPULAT')

# %%
from matplotlib import pyplot as plt
_df_8.plot(kind='scatter', x='CLUSTERS', y='TOTPOPULAT', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_3['CLUSTERS'].plot(kind='hist', bins=20, title='CLUSTERS')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#COLLAGE DATA

import pandas as pd

# Load the CSV file
file_path = '/content/College_data.csv'
college_data = pd.read_csv('/content/College_data.csv')

# Display the first few rows of the dataframe
college_data.head()
# Out:
#                                College_Name       State       Stream  \
# 0    Indian Institute of Technology Madras   Tamil nadu  Engineering
# 1  College of Engineering, Anna University   Tamil nadu  Engineering
# 2              NIT Trichy, Tiruchirappalli   Tamil nadu  Engineering
# 3          Vellore Institute of Technology   Tamil nadu  Engineering
# 4     SRM Engineering College, Kanchipuram   Tamil nadu  Engineering
#
#      UG_fee    PG_fee Rating Academic Accommodation Faculty Infrastructure  \
# 0    75,116    23,070    8.7        9           7.9     8.7            8.8
# 1    50,000    50,000    8.4      8.7           7.7     8.1            8.7
# 2  1,49,250    99,250    8.5      8.6           7.8     8.2            8.7
# 3  1,98,000  1,83,000    8.3      8.3             8     7.8            8.9
# 4  2,60,000  1,70,000    7.2      6.5           6.6     6.9            7.6
#
#   Placement Social_Life
# 0       8.8           9
# 1       8.3         8.7
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_50.groupby('Rating').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_49.groupby('PG_fee').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_48.groupby('UG_fee').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_47.groupby('College_Name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['UG_fee'].value_counts()
    for x_label, grp in _df_51.groupby('College_Name')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('College_Name')
_ = plt.ylabel('UG_fee')

# %%
#State-wise distribution of colleges
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import plotly.express as px
from bokeh.plotting import figure, show
df = pd.read_csv('/content/State-wise distribution of colleges.csv')
df.head()
# Out:
#                State  Central University  Central Open University  \
# 0     Andhra Pradesh                   2                        3
# 1  Arunachal Pradesh                   0                        0
# 2              Assam                   1                        0
# 3              Bihar                   2                        0
# 4         Chandigarh                   2                        0
#
#    Institute of National Importance  Others  State Public University  \
# 0                                 4       5                        6
# 1                                 1       1                       20
# 2                                 1       0                        0
# 3                                 2       1                       11
# 4                                 3       0                       14
#
#    Institute under State Legislature Act  State Open University  \
# 0                                      7                      8
# ...

# %%
# @title Central Open University vs Institute of National Importance

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Central Open University', y='Institute of National Importance', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_98.groupby('State').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Central University

from matplotlib import pyplot as plt
df['Central University'].plot(kind='hist', bins=20, title='Central University')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Central University vs Central Open University

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Central University', y='Central Open University', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
import pandas as pd
df = pd.read_csv('/content/engineering colleges in India.csv')
df.head()
# Out:
#                                         College Name Genders Accepted  \
# 0         National Institute of Technology Rourkela             Co-Ed
# 1  Visvesvaraya National Institute of Technology ...            Co-Ed
# 2             Netaji Subhas University of Technology            Co-Ed
# 3                      Birla Institute of Technology            Co-Ed
# 4  International Institute of Information Technology            Co-Ed
#
#   Campus Size Total Student Enrollments Total Faculty Established Year Rating  \
# 0   647 Acres                      4811           329             2007   3.12
# 1   215 Acres                      1071           192             2007    NaN
# 2   145 Acres                      3759           101             2018    NaN
# 3   980 Acres                      4506           284             1955    NaN
# 4    66 Acres                      1721            85             2001   3.05
#
#   University                                            Courses  \
# ...

# %%
# @title Country vs College Type

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['College Type'].value_counts()
    for x_label, grp in df.groupby('Country')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Country')
_ = plt.ylabel('College Type')

# %%
# @title College Type

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('College Type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Genders Accepted

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Genders Accepted').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
